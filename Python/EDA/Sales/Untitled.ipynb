# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('vendas.csv', delimiter=';')

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 00:00:00  2017-10-02 00:00:00
# 1    delivered      2018-07-24 00:00:00  2018-07-26 00:00:00
# 2    delivered      2018-08-08 00:00:00  2018-08-08 00:00:00
# 3    delivered      2017-11-18 00:00:00  2017-11-18 00:00:00
# 4    delivered      2018-02-13 00:00:00  2018-02-13 00:00:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 00:00:00           2017-10-10 00:00:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111923 entries, 0 to 111922
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       111923 non-null  object
#  1   customer_id                    111923 non-null  object
#  2   order_status                   111923 non-null  object
#  3   order_purchase_timestamp       111923 non-null  object
#  4   order_approved_at              111808 non-null  object
#  5   order_delivered_carrier_date   110050 non-null  object
#  6   order_delivered_customer_date  108804 non-null  object
#  7   order_estimated_delivery_date  111923 non-null  object
#  8   order_item_id                  111206 non-null  float64
#  9   product_id                     111206 non-null  object
#  10  seller_id                      111206 non-null  object
#  11  shipping_limit_date            111206 non-null  object
# ...

# %%
df.drop(['order_id', 'customer_id', 'customer_unique_id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 00:00:00  2017-10-02 00:00:00
# 1    delivered      2018-07-24 00:00:00  2018-07-26 00:00:00
# 2    delivered      2018-08-08 00:00:00  2018-08-08 00:00:00
# 3    delivered      2017-11-18 00:00:00  2017-11-18 00:00:00
# 4    delivered      2018-02-13 00:00:00  2018-02-13 00:00:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 00:00:00           2017-10-10 00:00:00
# 1          2018-07-26 00:00:00           2018-08-07 00:00:00
# 2          2018-08-08 00:00:00           2018-08-17 00:00:00
# 3          2017-11-22 00:00:00           2017-12-02 00:00:00
# 4          2018-02-14 00:00:00           2018-02-16 00:00:00
#
#   order_estimated_delivery_date  order_item_id  \
# 0           2017-10-18 00:00:00            1.0
# 1           2018-08-13 00:00:00            1.0
# 2           2018-09-04 00:00:00            1.0
# ...

# %%
pricev = df.price.to_numpy()
fvalue = df.freight_value.to_numpy()
total = pricev + fvalue
total
# Out:
# array(['29,998,72', '118,722,76', '159,919,22', ..., '179,9940,59',
#        '179,9940,59', '68,518,36'], dtype=object)

# %%
df['total_value'] = df.price + df.freight_value
# Out:
# 0           29,998,72
# 1          118,722,76
# 2          159,919,22
# 3              4527,2
# 4            19,98,72
#              ...
# 111918      174,920,1
# 111919    205,9965,02
# 111920    179,9940,59
# 111921    179,9940,59
# 111922      68,518,36
# Name: total_value, Length: 111923, dtype: object
